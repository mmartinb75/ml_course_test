# %%
import pandas as pd
import os

# %%
train_data = pd.read_csv("../data/preprocessed/train_data.csv")

# %%
train_data.head()
# Out:
#       Price       city  Area    Location  No. of Bedrooms  Resale  \
# 0   4800000      Delhi   720       Delhi                3       1
# 1   7441000    Chennai   763  Medavakkam                2       0
# 2   3700000    Kolkata  1000   Keshtopur                3       0
# 3   5961000  Bangalore  1089  Carmelaram                2       0
# 4  11900000  Bangalore  1761      Kogilu                3       0
#
#    MaintenanceStaff  Gymnasium  SwimmingPool  LandscapedGardens  ...  \
# 0                 9          9             9                  9  ...
# 1                 9          9             9                  9  ...
# 2                 9          9             9                  9  ...
# 3                 0          1             1                  1  ...
# 4                 0          1             1                  1  ...
#
#    LiftAvailable  BED  VaastuCompliant  Microwave  GolfCourse  TV  \
# 0              9    9                9          9           9   9
# ...
