# %%
# Importamos mi librería
from utils import data_collecting_lean as dc
import os

# %%
# Ejemplo de uso:
data_path = "../data/source"
df_final, df_train, df_test = dc.read_and_concat_csv(data_path)

# %%
# Save the dataframe to a CSV file
preprocessed_path = "../data/preprocessed"
df_final.to_csv(os.path.join(preprocessed_path, "combined_data.csv"), index=False)
